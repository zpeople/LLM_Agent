# %%
import os
import sys
try:
    get_ipython
    current_dir = os.getcwd()
except NameError:
    current_dir = os.path.dirname(os.path.abspath(__file__))

# Set path，temporary path expansion
project_dir = os.path.abspath(os.path.join(current_dir, '..'))
if project_dir not in sys.path:
    sys.path.append(project_dir)

# %%
from crewai import Task, Crew, Process
from estate_agents import RealEstateAgents 
from crewai.tasks.conditional_task import ConditionalTask
from crewai.tasks.task_output import TaskOutput
from tools.tool import skip_execution
from tools_wrapper import get_yaml_config
IS_SKIP=True

# %%
class RealEstateCrew:
    def __init__(self, user_query):
        self.user_query = user_query
        self.output_path ="./result.md"
        self.history = []

        self.agents = self._initialize_agents()
        self.intent_task =self._update_intent_task()
        self.tasks = self._create_tasks()
        self.crew = self._create_crew()

    def _initialize_agents(self):
        """初始化所有智能体"""
        return {
            "intent_recognizer": RealEstateAgents.intent_recognition_agent(),
            "planner": RealEstateAgents.conversation_planner_agent(),
            "consultant": RealEstateAgents.property_consultant_agent(),
            "mortgage_expert": RealEstateAgents.mortgage_expert_agent()
        }
    
    def _update_intent_task(self):
        # 任务1：识别用户意图 
        identify_intent = Task(
            description=f"分析用户查询: '{self.user_query}'，确定用户的具体意图。 \
            可能的意图包括：购房、租房、查询特定区域房价、了解市场趋势、计算房贷等。\
            如果需要调用工具搜索类似的对话信息，来帮助你判断用户的意图。 \
            ",
            expected_output="明确的用户意图分类，例如：'用户想查询某地的住宅房价'，",
            agent=self.agents["intent_recognizer"]
        )
        return identify_intent
  
    def _create_tasks(self):
        """创建任务"""
        # 任务2：规划对话策略
        plan_conversation = Task(
            description="""根据识别出的用户意图，提取用户意图中位置、面积、户型、朝向等和购房有关的信息，规划下一步对话策略。
                            0. 检查是否已获取足够信息（位置、面积、户型、预算等关键信息）
                            1. 如果用户说"没有其他需求"类似语句，就直接标志"无需追问",把客户需求信息汇总给房产咨询用
                            2. 如果信息不足，明确需要追问的具体内容（例如："需要询问用户的购房预算和意向区域"）
                            3. 如果信息充足，直接生成"无需追问"标记并汇总信息准备回答框架
                            
                            输出格式要求：
                            - 第一行必须是"需要追问"或"无需追问"
                            - 后续内容为具体说明（追问的问题或回答框架）
                            - 追问的问题的格式为'{ask:问题内容}'
                            - 汇总的信息框架按照要素组装成键值对
                            """,

            expected_output="清晰的对话规划，包括是否需要追问用户，如果需要追问，追问什么信息，或者直接回答问题。" \
            "如果不需要追问就直接提供房产咨询",
            agent=self.agents["planner"],
            context=[ self.intent_task]
        )
        
        # 任务3：提供房产咨询
        provide_consultation = Task(
            description="根据用户意图和对话规划，为用户提供专业的房产咨询服务。如果需要，调用适当的工具获取数据。",
            expected_output="详细、有用的房产咨询回答，包括必要的数据和建议",
            agent=self.agents["consultant"],
            context=[  self.intent_task, plan_conversation],
            dependencies=[plan_conversation]  
        )
        
        # 任务4：处理房贷相关查询（条件任务，根据意图动态激活）
        handle_mortgage = Task(
            description="如果用户意图涉及房贷计算或贷款建议，提供详细的等额本金和等额本息计算结果和专业建议。",
            expected_output="输出一套户型介绍，对应的清晰的房贷计算结果和实用的贷款建议",
            agent=self.agents["mortgage_expert"],
            context=[  self.intent_task, plan_conversation],
            output_file=self.output_path
        )
    
        return {
            "plan_conversation": plan_conversation,
            "provide_consultation":provide_consultation,
            "handle_mortgage":handle_mortgage,
        
        }
   
    
    def _create_crew(self):
        """创建智能体团队"""
        return Crew(
            agents=[self.agents["intent_recognizer"],
                    self.agents["consultant"],
                    self.agents["mortgage_expert"]
                    ],
            tasks= [self.intent_task] + list(self.tasks.values()),
            process=Process.hierarchical,  # 层级流程，由规划者协调
            manager_agent=self.agents["planner"],  # 由对话规划专家作为管理器
            verbose=True
        )
    
    def run(self):
        """运行智能体团队"""
        return self.crew.kickoff()
    
    def run_task(self, task: Task, context=None):
        if context:
            task.context = context
        crew = Crew(agents=[task.agent], tasks=[task])
        return crew.kickoff()
    

    def run_dialog_flow(self,user_input):
        all_user_inputs = [item[0] for item in self.history]
        user_inputs_combined = "\n".join(all_user_inputs)  # 用换行符分隔
        self.user_query = user_inputs_combined+user_input  # 更新当前查询
        # Step 1: 识别意图
        self.intent_task =self._update_intent_task()
        intent_result = self.run_task( self.intent_task)
        
        # Step 2: 规划对话
        plan_result = self.run_task(self.tasks["plan_conversation"], context=[self.intent_task])
        print(type(plan_result))
        # 判断是否需要追问
        if "需要追问" in plan_result.raw:
            return plan_result  # 暂停流程，返回追问内容给用户
        
        # Step 3: 提供咨询（如果意图明确）
        consultation_result = self.run_task(self.tasks["provide_consultation"], context=[self.intent_task, self.tasks["plan_conversation"]])
        
        # Step 4: 房贷处理（如果意图涉及房贷）
  
    
        mortgage_result = self.run_task(self.tasks["handle_mortgage"], context=[self.intent_task, self.tasks["plan_conversation"]])
        return f"{consultation_result}\n\n{mortgage_result}"
        
        # return consultation_result
    
    def handle_user_input(self, user_input: str):
        result = self.run_dialog_flow(user_input)
        self.history.append((user_input, result))
        return result

# %%
@skip_execution(IS_SKIP)
def test_crew():
     # 用户查询示例
    user_queries = [
        "我想在天府新区买一套3居室的住宅，预算在100万到200万之间，首付预算50万，能帮我推荐一下吗？",
    ]
    query_num=0
    print("===== 处理用户查询 =====")
    print(f"用户查询: {user_queries[query_num]}\n")
    
    crew = RealEstateCrew(user_queries[query_num])
    result = crew.run()
    
    print("\n===== 最终回答 =====")
    print(result)

test_crew()

# %%
# @skip_execution(IS_SKIP)
def start_real_estate_chat():
    print("欢迎来到房产智能咨询助手！请输入您的问题（输入 '退出' 结束对话）")
    user_query=None
    crew = RealEstateCrew(user_query)  # 初始化时可以为空，后续每轮更新
    user_input=user_query
    while True:
        if user_query ==None:
            user_input = input("您：")
        if user_input.strip().lower() in ["退出", "exit", "quit"]:
            print("感谢使用房产助手，再见！")
            break
        
        response = crew.handle_user_input(user_input)
        print(f"助手：{response}\n")

start_real_estate_chat()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 17
#      14         response = crew.handle_user_input(user_input)
#      15         print(f"助手：{response}\n")
# ---> 17 start_real_estate_chat()
#
# Cell In[10], line 14, in start_real_estate_chat()
#      11     print("感谢使用房产助手，再见！")
#      12     break
# ---> 14 response = crew.handle_user_input(user_input)
#      15 print(f"助手：{response}\n")
#
# Cell In[8], line 133, in RealEstateCrew.handle_user_input(self, user_input)
#     132 def handle_user_input(self, user_input: str):
# --> 133     result = self.run_dialog_flow(user_input)
#     134     self.history.append((user_input, result))
#     135     return result
#
# Cell In[8], line 115, in RealEstateCrew.run_dialog_flow(self, user_input)
#     112 intent_result = self.run_task( self.intent_task)
#     114 # Step 2: 规划对话
# --> 115 plan_result = self.run_task(self.tasks["plan_conversation"], context=[self.intent_task])
#     116 print(type(plan_result))
#     117 # 判断是否需要追问
#
# Cell In[8], line 103, in RealEstateCrew.run_task(self, task, context)
#     101     task.context = context
#     102 crew = Crew(agents=[task.agent], tasks=[task])
# --> 103 return crew.kickoff()
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/crew.py:662, in Crew.kickoff(self, inputs)
#     659     self._handle_crew_planning()
#     661 if self.process == Process.sequential:
# --> 662     result = self._run_sequential_process()
#     663 elif self.process == Process.hierarchical:
#     664     result = self._run_hierarchical_process()
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/crew.py:776, in Crew._run_sequential_process(self)
#     774 def _run_sequential_process(self) -> CrewOutput:
#     775     """Executes tasks sequentially and returns the final output."""
# --> 776     return self._execute_tasks(self.tasks)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/crew.py:879, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     876     futures.clear()
#     878 context = self._get_context(task, task_outputs)
# --> 879 task_output = task.execute_sync(
#     880     agent=agent_to_use,
#     881     context=context,
#     882     tools=cast(List[BaseTool], tools_for_task),
#     883 )
#     884 task_outputs.append(task_output)
#     885 self._process_task_result(task, task_output)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/task.py:381, in Task.execute_sync(self, agent, context, tools)
#     374 def execute_sync(
#     375     self,
#     376     agent: Optional[BaseAgent] = None,
#     377     context: Optional[str] = None,
#     378     tools: Optional[List[BaseTool]] = None,
#     379 ) -> TaskOutput:
#     380     """Execute the task synchronously."""
# --> 381     return self._execute_core(agent, context, tools)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/task.py:445, in Task._execute_core(self, agent, context, tools)
#     443 self.processed_by_agents.add(agent.role)
#     444 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 445 result = agent.execute_task(
#     446     task=self,
#     447     context=context,
#     448     tools=tools,
#     449 )
#     451 pydantic_output, json_output = self._export_output(result)
#     452 task_output = TaskOutput(
#     453     name=self.name or self.description,
#     454     description=self.description,
#    (...)
#     460     output_format=self._get_output_format(),
#     461 )
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/agent.py:451, in Agent.execute_task(self, task, context, tools)
#     447         result = self._execute_with_timeout(
#     448             task_prompt, task, self.max_execution_time
#     449         )
#     450     else:
# --> 451         result = self._execute_without_timeout(task_prompt, task)
#     453 except TimeoutError as e:
#     454     # Propagate TimeoutError without retry
#     455     crewai_event_bus.emit(
#     456         self,
#     457         event=AgentExecutionErrorEvent(
#    (...)
#     461         ),
#     462     )
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/agent.py:547, in Agent._execute_without_timeout(self, task_prompt, task)
#     537 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     538     """Execute a task without a timeout.
#     539
#     540     Args:
#    (...)
#     545         The output of the agent.
#     546     """
# --> 547     return self.agent_executor.invoke(
#     548         {
#     549             "input": task_prompt,
#     550             "tool_names": self.agent_executor.tools_names,
#     551             "tools": self.agent_executor.tools_description,
#     552             "ask_for_human_input": task.human_input,
#     553         }
#     554     )["output"]
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:114, in CrewAgentExecutor.invoke(self, inputs)
#     111 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     113 try:
# --> 114     formatted_answer = self._invoke_loop()
#     115 except AssertionError:
#     116     self._printer.print(
#     117         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     118         color="red",
#     119     )
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:153, in CrewAgentExecutor._invoke_loop(self)
#     142     formatted_answer = handle_max_iterations_exceeded(
#     143         formatted_answer,
#     144         printer=self._printer,
#    (...)
#     148         callbacks=self.callbacks,
#     149     )
#     151 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 153 answer = get_llm_response(
#     154     llm=self.llm,
#     155     messages=self.messages,
#     156     callbacks=self.callbacks,
#     157     printer=self._printer,
#     158     from_task=self.task,
#     159 )
#     160 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     162 if isinstance(formatted_answer, AgentAction):
#     163     # Extract agent fingerprint if available
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:154, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent)
#     152 """Call the LLM and return the response, handling any invalid responses."""
#     153 try:
# --> 154     answer = llm.call(
#     155         messages,
#     156         callbacks=callbacks,
#     157         from_task=from_task,
#     158         from_agent=from_agent,
#     159     )
#     160 except Exception as e:
#     161     raise e
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/llm.py:1032, in LLM.call(self, messages, tools, callbacks, available_functions, from_task, from_agent)
#    1028         return self._handle_streaming_response(
#    1029             params, callbacks, available_functions, from_task, from_agent
#    1030         )
#    1031     else:
# -> 1032         return self._handle_non_streaming_response(
#    1033             params, callbacks, available_functions, from_task, from_agent
#    1034         )
#    1036 except LLMContextLengthExceededException:
#    1037     # Re-raise LLMContextLengthExceededException as it should be handled
#    1038     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#    1039     # whether to summarize the content or abort based on the respect_context_window flag
#    1040     raise
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/crewai/llm.py:813, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions, from_task, from_agent)
#     807 # --- 1) Make the completion call
#     808 try:
#     809     # Attempt to make the completion call, but catch context window errors
#     810     # and convert them to our own exception type for consistent handling
#     811     # across the codebase. This allows CrewAgentExecutor to handle context
#     812     # length issues appropriately.
# --> 813     response = litellm.completion(**params)
#     815 except ContextWindowExceededError as e:
#     816     # Convert litellm's context window error to our own exception type
#     817     # for consistent handling in the rest of the codebase
#     818     raise LLMContextLengthExceededException(str(e))
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/litellm/utils.py:1205, in client.<locals>.wrapper(*args, **kwargs)
#    1203         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1204 # MODEL CALL
# -> 1205 result = original_function(*args, **kwargs)
#    1206 end_time = datetime.datetime.now()
#    1207 if _is_streaming_request(
#    1208     kwargs=kwargs,
#    1209     call_type=call_type,
#    1210 ):
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/litellm/main.py:1939, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1937 ## COMPLETION CALL
#    1938 try:
# -> 1939     response = openai_chat_completions.completion(
#    1940         model=model,
#    1941         messages=messages,
#    1942         headers=headers,
#    1943         model_response=model_response,
#    1944         print_verbose=print_verbose,
#    1945         api_key=api_key,
#    1946         api_base=api_base,
#    1947         acompletion=acompletion,
#    1948         logging_obj=logging,
#    1949         optional_params=optional_params,
#    1950         litellm_params=litellm_params,
#    1951         logger_fn=logger_fn,
#    1952         timeout=timeout,  # type: ignore
#    1953         custom_prompt_dict=custom_prompt_dict,
#    1954         client=client,  # pass AsyncOpenAI, OpenAI client
#    1955         organization=organization,
#    1956         custom_llm_provider=custom_llm_provider,
#    1957     )
#    1958 except Exception as e:
#    1959     ## LOGGING - log the original exception returned
#    1960     logging.post_call(
#    1961         input=messages,
#    1962         api_key=api_key,
#    1963         original_response=str(e),
#    1964         additional_args={"headers": headers},
#    1965     )
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/litellm/llms/openai/openai.py:653, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     638 ## LOGGING
#     639 logging_obj.pre_call(
#     640     input=messages,
#     641     api_key=openai_client.api_key,
#    (...)
#     647     },
#     648 )
#     650 (
#     651     headers,
#     652     response,
# --> 653 ) = self.make_sync_openai_chat_completion_request(
#     654     openai_client=openai_client,
#     655     data=data,
#     656     timeout=timeout,
#     657     logging_obj=logging_obj,
#     658 )
#     660 logging_obj.model_call_details["response_headers"] = headers
#     661 stringified_response = response.model_dump()
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/litellm/litellm_core_utils/logging_utils.py:149, in track_llm_api_timing.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     147 start_time = datetime.now()
#     148 try:
# --> 149     result = func(*args, **kwargs)
#     150     return result
#     151 finally:
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/litellm/llms/openai/openai.py:453, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     451 raw_response = None
#     452 try:
# --> 453     raw_response = openai_client.chat.completions.with_raw_response.create(
#     454         **data, timeout=timeout
#     455     )
#     457     if hasattr(raw_response, "headers"):
#     458         headers = dict(raw_response.headers)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/openai/_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:1150, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1104 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1105 def create(
#    1106     self,
#    (...)
#    1147     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1148 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1149     validate_response_format(response_format)
# -> 1150     return self._post(
#    1151         "/chat/completions",
#    1152         body=maybe_transform(
#    1153             {
#    1154                 "messages": messages,
#    1155                 "model": model,
#    1156                 "audio": audio,
#    1157                 "frequency_penalty": frequency_penalty,
#    1158                 "function_call": function_call,
#    1159                 "functions": functions,
#    1160                 "logit_bias": logit_bias,
#    1161                 "logprobs": logprobs,
#    1162                 "max_completion_tokens": max_completion_tokens,
#    1163                 "max_tokens": max_tokens,
#    1164                 "metadata": metadata,
#    1165                 "modalities": modalities,
#    1166                 "n": n,
#    1167                 "parallel_tool_calls": parallel_tool_calls,
#    1168                 "prediction": prediction,
#    1169                 "presence_penalty": presence_penalty,
#    1170                 "prompt_cache_key": prompt_cache_key,
#    1171                 "reasoning_effort": reasoning_effort,
#    1172                 "response_format": response_format,
#    1173                 "safety_identifier": safety_identifier,
#    1174                 "seed": seed,
#    1175                 "service_tier": service_tier,
#    1176                 "stop": stop,
#    1177                 "store": store,
#    1178                 "stream": stream,
#    1179                 "stream_options": stream_options,
#    1180                 "temperature": temperature,
#    1181                 "tool_choice": tool_choice,
#    1182                 "tools": tools,
#    1183                 "top_logprobs": top_logprobs,
#    1184                 "top_p": top_p,
#    1185                 "user": user,
#    1186                 "verbosity": verbosity,
#    1187                 "web_search_options": web_search_options,
#    1188             },
#    1189             completion_create_params.CompletionCreateParamsStreaming
#    1190             if stream
#    1191             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1192         ),
#    1193         options=make_request_options(
#    1194             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1195         ),
#    1196         cast_to=ChatCompletion,
#    1197         stream=stream or False,
#    1198         stream_cls=Stream[ChatCompletionChunk],
#    1199     )
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/agent/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/envs/agent/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/miniconda3/envs/agent/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
